# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# matplotlib configuration
sns.set_style(style='ticks')
sns.set_theme(style="ticks")
sns.set(rc={'figure.figsize':(11.7,8.27)})
# plt.rcParams['figure.figsize'] = 10, 7.5
# plt.rcParams['axes.grid'] = True
# plt.gray()

# pandas configuration
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)

# %%
df = pd.read_csv('Airbnb_Open_Data.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long instant_bookable cancellation_policy        room type  \
# 0  40.64749 -73.97237            False              strict     Private room
# 1  40.75362 -73.98377            False            moderate  Entire home/apt
# 2  40.80902 -73.94190             True            flexible     Private room
# 3  40.68514 -73.95976             True            moderate  Entire home/apt
# 4  40.79851 -73.94399            False            moderate  Entire home/apt
#
#    Construction year  price service fee  minimum nights  number of reviews  \
# 0             2020.0  $966        $193             10.0                9.0
# 1             2007.0  $142         $28             30.0               45.0
# 2             2005.0  $620        $124              3.0                0.0
# 3             2005.0  $368         $74             30.0              270.0
# 4             2009.0  $204         $41             10.0                9.0
#
#   last review  reviews per month  review rate number  \
# 0  10/19/2021               0.21                 4.0
# 1   5/21/2022               0.38                 4.0
# 2         NaN                NaN                 5.0
# 3  07/05/2019               4.64                 4.0
# 4  11/19/2018               0.10                 3.0
#
#    calculated host listings count  availability 365  \
# 0                             6.0             286.0
# 1                             2.0             228.0
# 2                             1.0             352.0
# 3                             1.0             322.0
# 4                             1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN

# %% [markdown]
# #### Overview of total number of rows with missing columns

# %%
df.isna().sum(axis=0)
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified               289
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# availability 365                     448
# house_rules                        52131
# license                           102597
# dtype: int64

# %% [markdown]
# #### Fill Variable - Name

# %%
# since it does not seem like there are any peculiarities with unnamed listings, a temporal placeholder 
#is used as it should not affect the data in any significant way
df['NAME'].fillna('Sample', inplace=True)

# %% [markdown]
# #### Drop Variable - License

# %%
# There are only two entries with a valid license, making it an extreme outlier, so it would be easier to 
# drop the selection entirely
df.drop(columns = 'license', inplace=True)

# %% [markdown]
# #### Fill Variable - Host Identity

# %%
df.loc[df['host_identity_verified'].isna()].isna().sum(axis = 1).value_counts()
# Out:
# 1    112
# 2    101
# 3     45
# 4     28
# 5      2
# 6      1
# dtype: int64

# %%
# as long as there are no extreme outliers with too many instances of information missing, it should be fine
# to simply replace the null values with the standard placeholders 
# in this case, null values and unconfirmed verification is essentially the same thing
df['host_identity_verified'].fillna('unconfirmed', inplace=True)

# %% [markdown]
# #### Fill Variable - Host Name

# %%
# again, host name is an inconsequential data that should not affect things in the grand scheme and a simple
# placeholder is put in place
df['host name'].fillna('unfilled', inplace=True)

# %% [markdown]
# ##### Taking a look at construction year - the distribution of construction year across the data set is fairly symmetrical at 0.12

# %%
df_dropped.isna().sum(axis=1).value_counts()
# Out:
# 2    879
# 1    699
# 3    348
# 4    279
# 5     57
# dtype: int64

# %%
g = sns.barplot(
    x = df['Construction year'].value_counts().index.astype(int), 
    y = df['Construction year'].value_counts().values.astype(int),
    color = '#8dbdc2'
)
plt.xticks(rotation=70)
# plt.tight_layout()
plt.title('Distribution of construction year', fontsize = 13)

from scipy.stats import skew
print('Skewness: ' , skew(df['Construction year'].value_counts().values))
# Out:
# Skewness:  0.17406046745138534

# %% [markdown]
# #### Overview of shape of data with missing values in associating columns

# %%
df.isna().sum()
# Out:
# id                                    0
# NAME                                  0
# host id                               0
# host_identity_verified                0
# host name                             0
# neighbourhood group                  29
# neighbourhood                        16
# lat                                   8
# long                                  8
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                   214
# price                               247
# service fee                         273
# minimum nights                      409
# number of reviews                   183
# last review                       15893
# reviews per month                 15879
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# house_rules                       52131
# dtype: int64

# %%
target_columns = df.columns.to_list()
#since last review, review per month and house rules has larger counts of missing values, 
#they will be excluded from the selection to avoid removing too much information from the data
target_columns.remove('last review')
target_columns.remove('reviews per month')
target_columns.remove('house_rules')

# %%
print('Shape of data with at least one missing value in selected columns:' , 
      df[~df[target_columns].notnull().all(axis=1)].shape)
print('Shape of data outside above selection:' , 
      df[df[target_columns].notnull().all(axis=1)].shape)
# Out:
# Shape of data with at least one missing value in selected columns: (2262, 23)
# Shape of data outside above selection: (100337, 23)

# %% [markdown]
# ##### Going forward, we will drop 2262 values with missing values in target column to obtain cleaner data since the missing values are easier to address, effectively stripping away 2.25% of the data

# %%
df_filtered = df[df[target_columns].notnull().all(axis=1)].copy()
df_dropped = df[~df[target_columns].notnull().all(axis=1)].copy()

# %%
df_dropped.isna().sum()
# Out:
# id                                   0
# NAME                                 0
# host id                              0
# host_identity_verified               0
# host name                            0
# neighbourhood group                 29
# neighbourhood                       16
# lat                                  8
# long                                 8
# instant_bookable                   105
# cancellation_policy                 76
# room type                            0
# Construction year                  214
# price                              247
# service fee                        273
# minimum nights                     409
# number of reviews                  183
# last review                        564
# reviews per month                  548
# review rate number                 326
# calculated host listings count     319
# availability 365                   448
# house_rules                       1129
# dtype: int64

# %%
df_dropped.describe()
# Out:
#                  id       host id          lat         long  \
# count  2.262000e+03  2.262000e+03  2254.000000  2254.000000
# mean   2.362356e+07  4.986242e+10    40.730173   -73.950539
# std    1.732790e+07  2.846184e+10     0.055396     0.046820
# min    1.009621e+06  1.998133e+08    40.542500   -74.148090
# 25%    7.418372e+06  2.559805e+10    40.689782   -73.981840
# 50%    2.551876e+07  5.037497e+10    40.723535   -73.954235
# 75%    3.725527e+07  7.467290e+10    40.762478   -73.934530
# max    5.736742e+07  9.871525e+10    40.904840   -73.729590
#
#        Construction year  minimum nights  number of reviews  \
# count        2048.000000     1853.000000        2079.000000
# mean         2012.576172       10.660011          36.996633
# std             5.920666       83.521624          66.414015
# min          2003.000000       -5.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# 50%          2013.000000        3.000000           8.000000
# 75%          2018.000000        6.000000          44.000000
# max          2022.000000     3455.000000         597.000000
#
#        reviews per month  review rate number  calculated host listings count  \
# count        1714.000000         1936.000000                     1943.000000
# mean            1.348757            3.228306                        6.835306
# std             1.788222            1.316382                       27.237666
# min             0.010000            1.000000                        1.000000
# 25%             0.190000            2.000000                        1.000000
# 50%             0.730000            3.000000                        1.000000
# 75%             1.900000            4.000000                        3.000000
# max            26.110000            5.000000                      332.000000
#
#        availability 365  missing_cols
# count       1814.000000   2262.000000
# mean         159.438809      1.167109
# std          137.475651      1.074993
# min          -10.000000      0.000000
# 25%           21.000000      0.000000
# 50%          141.500000      1.000000
# 75%          287.000000      2.000000
# max          426.000000      4.000000

# %%
sns.heatmap(df_dropped.isna().T, cmap="YlGnBu",)
# Out:
# <AxesSubplot:>

# %%
df_dropped['missing_cols'] = df_dropped.apply(lambda x: 23 - x.count(), axis=1)
df_dropped[df_dropped['missing_cols'] >= 4]
# Out:
#               id                                               NAME  \
# 205      1114558                                             Sample
# 266      1148248             HOSTING YOUR  SUNNY, SPACIOUS NYC ROOM
# 332      1184700                Columbia Castle in Brooklyn Heights
# 336      1186909               Brooklyn Cove Studio Apt w/ Garden!!
# 926      1512766                    21 day Chelsea Apartment rental
# 13601    8513168                  Gorgeous and Sunlit 1 BR 31/1-3/1
# 48553   27817158         Quiet, cozy and clean walkup in Greenpoint
# 48685   27890062                                       Comfort home
# 48761   27932036  Sunnyside, Queens 15 Mins to Midtown Clean & C...
# 48762   27932589    1900s 1 Bed Rockaway Beach Bungalow-ByMTA&Beach
# 48764   27933693                     House feeling in Caroll Garden
# 48766   27934798                    Cozy Room with Private Bathroom
# 48767   27935350  3 Br ✰ Prime Williamsburg ✰ | 5 min to Manhatt...
# 48768   27935902  Romantic studio in New York artistic best Bush...
# 48769   27936455       Private room in beautiful Williamsburg loft!
# 48770   27937007   Williamsburg: private bright bedroom - cosy appt
# 48771   27937559     City and water views, 1 BR w/ private terrace!
# 48772   27938112                    Modern room in luxury apartment
# 48874   27994446                                  Brooklyn paradise
# 48876   27995551                              Welcome all as family
# 48879   27997208                                      Room for rest
# 48880   27997760  Gorgeous 1.5 Bdr with a private yard- Williams...
# 48881   27998312  The Raccoon Artist Studio in Williamsburg New ...
# 49238   28195483                 July Steal! Up to one month sublet
# 49239   28196036         Quiet, cozy and clean walkup in Greenpoint
# 49240   28196588  Lg and Lovely 2 bedroom in Astoria. Sleeps up ...
# 49241   28197140              Cute Bedroom in the heart of Bushwick
# 49242   28197693        TRANQUIL HAVEN -8MINS TO JFK/LIRR/AIRTRAIN.
# 49371   28268939                                       Comfort home
# 49372   28269492    Spacious Astoria Apartment in a Prime Location!
# 49447   28310914  Sunnyside, Queens 15 Mins to Midtown Clean & C...
# 49448   28311466    1900s 1 Bed Rockaway Beach Bungalow-ByMTA&Beach
# 49449   28312019  Nice & Lovely room in LIC.5 stops to Times Square
# 49450   28312571                     House feeling in Caroll Garden
# 49451   28313123    Luxury | Private room |Balcony|Parking included
# 49452   28313676                    Cozy Room with Private Bathroom
# 49453   28314228  3 Br ✰ Prime Williamsburg ✰ | 5 min to Manhatt...
# 49454   28314780  Romantic studio in New York artistic best Bush...
# 49455   28315333       Private room in beautiful Williamsburg loft!
# 49456   28315885   Williamsburg: private bright bedroom - cosy appt
# 49457   28316437     City and water views, 1 BR w/ private terrace!
# 49458   28316989                    Modern room in luxury apartment
# 49560   28373324                                  Brooklyn paradise
# 49561   28373876                   Short Term Rental in East Harlem
# 49562   28374429                              Welcome all as family
# 49563   28374981    Cozy, Air-Conditioned Private Bedroom in Harlem
# 49564   28375533             Studio sized room with beautiful light
# 49565   28376086                                      Room for rest
# 49566   28376638  Gorgeous 1.5 Bdr with a private yard- Williams...
# 49567   28377190  The Raccoon Artist Studio in Williamsburg New ...
# 79786   45067144                           Charming, small and cozy
# 79788   45068248      Beautiful 1 bedroom Apartment in Midtown East
# 83527   47133298                 Creative Artist Apartment in SoBro
# 83528   47133850                  Prime East Village REAL 1 Bedroom
# 99689   56059571                 Large modern one bedroom apartment
# 102045  57360790        Private Bedroom in Rego Park / Forest Hills
# 102051  57364103                A cozy getaway, home away from home
#
#             host id host_identity_verified       host name  \
# 205     27207072817            unconfirmed            Jack
# 266     84001079377               verified        unfilled
# 332     19318123506            unconfirmed        Crawford
# 336     77105495927               verified         Hawkins
# 926     10876728736            unconfirmed           Owens
# 13601   97784918895               verified             Shy
# 48553   39192800547            unconfirmed           David
# 48685   10097604670               verified             Yan
# 48761   28306951226            unconfirmed         Brandon
# 48762   54804206383            unconfirmed       Elizabeth
# 48764   31503331940            unconfirmed           Tarek
# 48766   95968850277               verified         Matheus
# 48767   60688958626               verified          Feliks
# 48768   97465590218               verified       Alexander
# 48769   33126715212            unconfirmed           Perry
# 48770   16789968286               verified          Pierre
# 48771   88447242547            unconfirmed             Dan
# 48772   15877824262            unconfirmed           Elena
# 48874   58605370344            unconfirmed  Clement & Rose
# 48876    3666789951               verified       Anastasia
# 48879   36583676349            unconfirmed     Jeerathinan
# 48880   27558039763            unconfirmed             Lee
# 48881   37925218790            unconfirmed           Melki
# 49238   86335880878               verified       Stephanie
# 49239   49226763819            unconfirmed           David
# 49240   11337269578               verified              Jp
# 49241   57128652969            unconfirmed        Geoffrey
# 49242   54335015078               verified          Sharon
# 49371   28084366917               verified             Yan
# 49372   39737844093            unconfirmed           Tracy
# 49447   47692025956               verified         Brandon
# 49448   31135908888               verified       Elizabeth
# 49449   79171071012               verified           Karma
# 49450   70448499763               verified           Tarek
# 49451   23714969136               verified        Stefania
# 49452   56368278376               verified         Matheus
# 49453    9894805829            unconfirmed          Feliks
# 49454   97029732636               verified       Alexander
# 49455   51888875237            unconfirmed           Perry
# 49456    1997408005            unconfirmed          Pierre
# 49457   27660186782               verified             Dan
# 49458   80973710411            unconfirmed           Elena
# 49560   74674021292               verified  Clement & Rose
# 49561   80773924517               verified         Jeffrey
# 49562   42461135261               verified       Anastasia
# 49563   27870518565               verified          Joseph
# 49564   27517082172               verified         Melanie
# 49565   83028824372            unconfirmed     Jeerathinan
# 49566   43159985041            unconfirmed             Lee
# 49567   77017955185               verified           Melki
# 79786   30529609513               verified          Ashley
# 79788   57258447305            unconfirmed          Sheena
# 83527   42128629166            unconfirmed        Jermaine
# 83528   50727450322               verified           David
# 99689   82539184022            unconfirmed           Aliya
# 102045  15978912806            unconfirmed        unfilled
# 102051  55697801194               verified          Isaiah
#
#        neighbourhood group      neighbourhood       lat      long  \
# 205              Manhattan             Harlem  40.80234 -73.95603
# 266              Manhattan             Inwood  40.86648 -73.92630
# 332               Brooklyn   Brooklyn Heights  40.69260 -73.99832
# 336               Brooklyn           Bushwick  40.68949 -73.91708
# 926              Manhattan  Flatiron District       NaN       NaN
# 13601                Bronx          Bronxdale  40.85592 -73.86743
# 48553             Brooklyn         Greenpoint  40.72673 -73.95223
# 48685             Brooklyn        Sunset Park  40.64439 -74.01816
# 48761               Queens          Sunnyside  40.74719 -73.91919
# 48762               Queens     Rockaway Beach  40.58893 -73.81347
# 48764             Brooklyn    Carroll Gardens  40.67666 -73.99981
# 48766             Brooklyn         Greenpoint  40.73164 -73.95187
# 48767             Brooklyn       Williamsburg  40.70626 -73.94699
# 48768             Brooklyn           Bushwick  40.69958 -73.92772
# 48769             Brooklyn       Williamsburg  40.70538 -73.94314
# 48770             Brooklyn       Williamsburg  40.71175 -73.96197
# 48771            Manhattan        Murray Hill  40.74604 -73.97228
# 48772             Brooklyn         Greenpoint  40.71918 -73.94853
# 48874             Brooklyn          Flatlands  40.63116 -73.92616
# 48876            Manhattan        East Harlem  40.78749 -73.94749
# 48879               Queens           Elmhurst  40.74477 -73.87727
# 48880             Brooklyn       Williamsburg  40.71728 -73.94394
# 48881             Brooklyn       Williamsburg  40.71232 -73.94220
# 49238            Manhattan             Harlem  40.82539 -73.94880
# 49239             Brooklyn         Greenpoint  40.72673 -73.95223
# 49240               Queens            Astoria  40.75825 -73.90959
# 49241             Brooklyn           Bushwick  40.70469 -73.92458
# 49242               Queens            Jamaica  40.67100 -73.77911
# 49371             Brooklyn        Sunset Park  40.64439 -74.01816
# 49372               Queens            Astoria  40.76389 -73.91963
# 49447               Queens          Sunnyside  40.74719 -73.91919
# 49448               Queens     Rockaway Beach  40.58893 -73.81347
# 49449               Queens          Sunnyside  40.73799 -73.92749
# 49450             Brooklyn    Carroll Gardens  40.67666 -73.99981
# 49451               Queens    Jackson Heights  40.74765 -73.89445
# 49452             Brooklyn         Greenpoint  40.73164 -73.95187
# 49453             Brooklyn       Williamsburg  40.70626 -73.94699
# 49454             Brooklyn           Bushwick  40.69958 -73.92772
# 49455             Brooklyn       Williamsburg  40.70538 -73.94314
# 49456             Brooklyn       Williamsburg  40.71175 -73.96197
# 49457            Manhattan        Murray Hill  40.74604 -73.97228
# 49458             Brooklyn         Greenpoint  40.71918 -73.94853
# 49560             Brooklyn          Flatlands  40.63116 -73.92616
# 49561            Manhattan        East Harlem  40.79760 -73.93947
# 49562            Manhattan        East Harlem  40.78749 -73.94749
# 49563            Manhattan             Harlem  40.80953 -73.95410
# 49564             Brooklyn           Bushwick  40.70418 -73.91471
# 49565               Queens           Elmhurst  40.74477 -73.87727
# 49566             Brooklyn       Williamsburg  40.71728 -73.94394
# 49567             Brooklyn       Williamsburg  40.71232 -73.94220
# 79786             Brooklyn      East Flatbush  40.63676 -73.95033
# 79788            Manhattan            Midtown  40.75242 -73.97112
# 83527                Bronx         Mott Haven  40.81553 -73.92453
# 83528            Manhattan       East Village  40.72236 -73.97756
# 99689            Manhattan        East Harlem  40.78982 -73.94263
# 102045              Queens          Rego Park  40.72460 -73.85688
# 102051            Brooklyn      East New York  40.66130 -73.89088
#
#        instant_bookable cancellation_policy        room type  \
# 205                 NaN                 NaN     Private room
# 266               False              strict     Private room
# 332               False            moderate     Private room
# 336                True            moderate  Entire home/apt
# 926               False              strict     Private room
# 13601              True              strict  Entire home/apt
# 48553              True            moderate     Private room
# 48685              True            moderate     Private room
# 48761              True            flexible     Private room
# 48762              True            flexible  Entire home/apt
# 48764             False            moderate  Entire home/apt
# 48766             False            moderate     Private room
# 48767              True              strict  Entire home/apt
# 48768              True              strict  Entire home/apt
# 48769             False            moderate     Private room
# 48770              True            moderate     Private room
# 48771              True            flexible  Entire home/apt
# 48772              True              strict     Private room
# 48874             False              strict  Entire home/apt
# 48876              True            moderate     Private room
# 48879             False            flexible     Private room
# 48880             False            flexible  Entire home/apt
# 48881              True            flexible  Entire home/apt
# 49238             False            moderate     Private room
# 49239              True            moderate     Private room
# 49240              True            flexible  Entire home/apt
# 49241             False            moderate     Private room
# 49242              True              strict  Entire home/apt
# 49371             False            moderate     Private room
# 49372              True              strict     Private room
# 49447             False            flexible     Private room
# 49448             False            flexible  Entire home/apt
# 49449             False            moderate     Private room
# 49450             False            moderate  Entire home/apt
# 49451              True            flexible     Private room
# 49452             False            moderate     Private room
# 49453             False            moderate  Entire home/apt
# 49454              True            flexible  Entire home/apt
# 49455             False            moderate     Private room
# 49456             False            moderate     Private room
# 49457              True            flexible  Entire home/apt
# 49458              True            flexible     Private room
# 49560             False              strict  Entire home/apt
# 49561              True              strict     Private room
# 49562              True            flexible     Private room
# 49563             False            flexible     Private room
# 49564             False            moderate     Private room
# 49565              True            flexible     Private room
# 49566             False            moderate  Entire home/apt
# 49567             False            moderate  Entire home/apt
# 79786             False            moderate     Private room
# 79788             False            moderate     Private room
# 83527               NaN                 NaN  Entire home/apt
# 83528               NaN                 NaN  Entire home/apt
# 99689              True            moderate  Entire home/apt
# 102045            False            moderate     Private room
# 102051             True            moderate     Private room
#
#         Construction year    price service fee  minimum nights  \
# 205                   NaN    $112         $22             30.0
# 266                2003.0    $373         $75              7.0
# 332                2022.0    $981        $196              NaN
# 336                   NaN    $824        $165              NaN
# 926                2020.0    $623        $125             21.0
# 13601              2005.0      NaN         NaN             7.0
# 48553              2015.0    $831        $166              3.0
# 48685              2017.0    $968        $194              1.0
# 48761              2013.0    $804        $161              1.0
# 48762              2018.0    $162         $32              1.0
# 48764              2013.0    $399         $80             30.0
# 48766              2019.0    $508        $102              1.0
# 48767              2015.0    $149         $30              4.0
# 48768              2009.0    $916        $183              1.0
# 48769              2022.0    $417         $83              2.0
# 48770              2003.0    $242         $48              6.0
# 48771              2008.0    $387         $77              5.0
# 48772              2019.0    $199         $40              1.0
# 48874              2003.0  $1,061        $212              1.0
# 48876              2019.0    $994        $199              1.0
# 48879              2005.0  $1,085        $217              1.0
# 48880              2004.0    $731        $146             20.0
# 48881              2021.0    $338         $68              1.0
# 49238              2015.0    $110         $22              1.0
# 49239              2021.0  $1,166        $233              3.0
# 49240              2007.0    $439         $88              3.0
# 49241              2007.0    $902        $180              7.0
# 49242              2012.0    $869        $174              1.0
# 49371              2011.0    $771        $154              1.0
# 49372              2008.0    $547        $109              4.0
# 49447              2008.0  $1,160        $232              1.0
# 49448              2018.0    $778        $156              1.0
# 49449              2009.0    $496         $99              1.0
# 49450              2012.0  $1,014        $203             30.0
# 49451              2019.0     $94         $19              2.0
# 49452              2018.0    $440         $88              1.0
# 49453              2006.0  $1,077        $215              4.0
# 49454              2016.0    $122         $24              1.0
# 49455              2008.0    $134         $27              2.0
# 49456              2013.0    $961        $192              6.0
# 49457              2019.0    $241         $48              5.0
# 49458              2011.0    $308         $62              1.0
# 49560              2003.0    $656        $131              1.0
# 49561              2013.0    $257         $51              7.0
# 49562              2012.0    $845        $169              1.0
# 49563              2020.0     $59         $12              1.0
# 49564              2003.0    $201         $40              7.0
# 49565              2022.0    $357         $71              1.0
# 49566              2021.0    $920        $184             20.0
# 49567              2007.0    $939        $188              1.0
# 79786              2004.0      NaN         NaN             2.0
# 79788              2006.0      NaN         NaN             3.0
# 83527              2015.0    $513        $103              2.0
# 83528              2019.0  $1,153        $231              5.0
# 99689              2014.0    $481         $96              7.0
# 102045             2006.0      NaN         NaN             1.0
# 102051                NaN    $147          NaN             1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 205                   0.0         NaN                NaN                 1.0
# 266                   0.0         NaN                NaN                 NaN
# 332                  66.0   9/16/2016                NaN                 NaN
# 336                 228.0         NaN               2.27                 1.0
# 926                   0.0         NaN                NaN                 2.0
# 13601                 0.0         NaN                NaN                 2.0
# 48553                 NaN         NaN                NaN                 4.0
# 48685                 NaN         NaN                NaN                 2.0
# 48761                 NaN         NaN                NaN                 5.0
# 48762                 NaN         NaN                NaN                 5.0
# 48764                 NaN         NaN                NaN                 3.0
# 48766                 NaN         NaN                NaN                 2.0
# 48767                 NaN         NaN                NaN                 4.0
# 48768                 NaN         NaN                NaN                 4.0
# 48769                 NaN         NaN                NaN                 4.0
# 48770                 NaN         NaN                NaN                 3.0
# 48771                 NaN         NaN                NaN                 4.0
# 48772                 NaN         NaN                NaN                 3.0
# 48874                 NaN         NaN                NaN                 3.0
# 48876                 NaN         NaN                NaN                 5.0
# 48879                 NaN         NaN                NaN                 4.0
# 48880                 NaN         NaN                NaN                 3.0
# 48881                 NaN         NaN                NaN                 3.0
# 49238                 NaN         NaN                NaN                 5.0
# 49239                 NaN         NaN                NaN                 4.0
# 49240                 NaN         NaN                NaN                 4.0
# 49241                 NaN         NaN                NaN                 4.0
# 49242                 NaN         NaN                NaN                 5.0
# 49371                 NaN         NaN                NaN                 5.0
# 49372                 NaN         NaN                NaN                 5.0
# 49447                 NaN         NaN                NaN                 3.0
# 49448                 NaN         NaN                NaN                 4.0
# 49449                 NaN         NaN                NaN                 2.0
# 49450                 NaN         NaN                NaN                 4.0
# 49451                 NaN         NaN                NaN                 3.0
# 49452                 NaN         NaN                NaN                 2.0
# 49453                 NaN         NaN                NaN                 3.0
# 49454                 NaN         NaN                NaN                 4.0
# 49455                 NaN         NaN                NaN                 4.0
# 49456                 NaN         NaN                NaN                 4.0
# 49457                 NaN         NaN                NaN                 5.0
# 49458                 NaN         NaN                NaN                 4.0
# 49560                 NaN         NaN                NaN                 3.0
# 49561                 NaN         NaN                NaN                 2.0
# 49562                 NaN         NaN                NaN                 3.0
# 49563                 NaN         NaN                NaN                 5.0
# 49564                 NaN         NaN                NaN                 5.0
# 49565                 NaN         NaN                NaN                 4.0
# 49566                 NaN         NaN                NaN                 5.0
# 49567                 NaN         NaN                NaN                 4.0
# 79786                 0.0         NaN                NaN                 1.0
# 79788                 0.0         NaN                NaN                 1.0
# 83527                 0.0         NaN                NaN                 3.0
# 83528                 0.0         NaN                NaN                 3.0
# 99689                 0.0         NaN                NaN                 NaN
# 102045                0.0         NaN                NaN                 3.0
# 102051                0.0         NaN                NaN                 4.0
#
#         calculated host listings count  availability 365  \
# 205                                1.0              12.0
# 266                                2.0               NaN
# 332                                2.0               NaN
# 336                                1.0               NaN
# 926                                1.0             104.0
# 13601                              1.0             192.0
# 48553                              1.0               NaN
# 48685                              2.0               NaN
# 48761                              1.0               NaN
# 48762                              4.0               NaN
# 48764                              1.0               NaN
# 48766                              1.0               NaN
# 48767                              1.0               NaN
# 48768                              1.0               NaN
# 48769                              1.0               NaN
# 48770                              1.0               NaN
# 48771                              1.0               NaN
# 48772                              3.0               NaN
# 48874                              2.0               NaN
# 48876                              1.0               NaN
# 48879                              5.0               NaN
# 48880                              1.0               NaN
# 48881                              3.0               NaN
# 49238                              1.0               NaN
# 49239                              1.0               NaN
# 49240                              1.0               NaN
# 49241                              1.0               NaN
# 49242                              4.0               NaN
# 49371                              2.0               NaN
# 49372                              1.0               NaN
# 49447                              1.0               NaN
# 49448                              4.0               NaN
# 49449                              1.0               NaN
# 49450                              1.0               NaN
# 49451                              1.0               NaN
# 49452                              1.0               NaN
# 49453                              1.0               NaN
# 49454                              1.0               NaN
# 49455                              1.0               NaN
# 49456                              1.0               NaN
# 49457                              1.0               NaN
# 49458                              3.0               NaN
# 49560                              2.0               NaN
# 49561                              1.0               NaN
# 49562                              1.0               NaN
# 49563                              1.0               NaN
# 49564                              1.0               NaN
# 49565                              5.0               NaN
# 49566                              1.0               NaN
# 49567                              3.0               NaN
# 79786                              1.0               0.0
# 79788                              1.0               0.0
# 83527                              1.0               0.0
# 83528                              1.0               0.0
# 99689                              NaN               0.0
# 102045                             1.0               0.0
# 102051                             1.0              88.0
#
#                                               house_rules  missing_cols
# 205     Shoes off please Cat can go in or out as he de...             4
# 266                                                   NaN             4
# 332                                                   NaN             4
# 336                                                   NaN             4
# 926                                                   NaN             4
# 13601                                                 NaN             4
# 48553                                                 NaN             4
# 48685                                                 NaN             4
# 48761                                                 NaN             4
# 48762                                                 NaN             4
# 48764                                                 NaN             4
# 48766                                                 NaN             4
# 48767                                                 NaN             4
# 48768                                                 NaN             4
# 48769                                                 NaN             4
# 48770                                                 NaN             4
# 48771                                                 NaN             4
# 48772                                                 NaN             4
# 48874                                                 NaN             4
# 48876                                                 NaN             4
# 48879                                                 NaN             4
# 48880                                                 NaN             4
# 48881                                                 NaN             4
# 49238                                                 NaN             4
# 49239                                                 NaN             4
# 49240                                                 NaN             4
# 49241                                                 NaN             4
# 49242                                                 NaN             4
# 49371                                                 NaN             4
# 49372                                                 NaN             4
# 49447                                                 NaN             4
# 49448                                                 NaN             4
# 49449                                                 NaN             4
# 49450                                                 NaN             4
# 49451                                                 NaN             4
# 49452                                                 NaN             4
# 49453                                                 NaN             4
# 49454                                                 NaN             4
# 49455                                                 NaN             4
# 49456                                                 NaN             4
# 49457                                                 NaN             4
# 49458                                                 NaN             4
# 49560                                                 NaN             4
# 49561                                                 NaN             4
# 49562                                                 NaN             4
# 49563                                                 NaN             4
# 49564                                                 NaN             4
# 49565                                                 NaN             4
# 49566                                                 NaN             4
# 49567                                                 NaN             4
# 79786                                                 NaN             4
# 79788                                                 NaN             4
# 83527                                                 NaN             4
# 83528                                                 NaN             4
# 99689                                                 NaN             4
# 102045                                                NaN             4
# 102051                                                NaN             4
